# %%
import requests
url = 'http://mops.twse.com.tw/nas/t21/sii/t21sc03_108_2_0.html'
r = requests.get(url)

# %%
from io import StringIO
import pandas as pd
r.encoding = 'big5'

# %%
dfs = pd.read_html(StringIO(r.text))

# %%
dfs[0]
# Out:
#                                                   0         1         2      \
# 0     產業別：水泥工業單位：千元 營業收入累計營業收入備註公司代號公司名稱當月營收上月營收去年當月...  產業別：水泥工業     單位：千元
# 1                                              產業別：水泥工業     單位：千元       NaN
# 2     營業收入累計營業收入備註公司代號公司名稱當月營收上月營收去年當月營收上月比較增減(%)去年同...       NaN      營業收入
# 3                                                   NaN      營業收入    累計營業收入
# 4                                                  公司代號      公司名稱      當月營收
# 5                                                  1101        台泥   5085162
# 6                                                  1102        亞泥   3165899
# 7                                                  1103        嘉泥    108448
# 8                                                  1104      環球水泥    270638
# 9                                                  1108      幸福水泥    168065
# 10                                                 1109      信大水泥    149960
# ...

# %%
df = dfs[0]
df=df[list(range(0,10))]

df.columns = df[df[0] == '公司代號'].iloc[0]
df
# Out:
# 4                                                  公司代號      公司名稱      當月營收  \
# 0     產業別：水泥工業單位：千元 營業收入累計營業收入備註公司代號公司名稱當月營收上月營收去年當月...  產業別：水泥工業     單位：千元
# 1                                              產業別：水泥工業     單位：千元       NaN
# 2     營業收入累計營業收入備註公司代號公司名稱當月營收上月營收去年當月營收上月比較增減(%)去年同...       NaN      營業收入
# 3                                                   NaN      營業收入    累計營業收入
# 4                                                  公司代號      公司名稱      當月營收
# 5                                                  1101        台泥   5085162
# 6                                                  1102        亞泥   3165899
# 7                                                  1103        嘉泥    108448
# 8                                                  1104      環球水泥    270638
# 9                                                  1108      幸福水泥    168065
# 10                                                 1109      信大水泥    149960
# ...

# %%
df = df[-pd.to_numeric(df['當月營收'],errors = 'coerce').isnull()]

# %%
df.head()
# Out:
# 4             當月營收     上月營收   去年當月營收  上月比較增減(%)  去年同月增減(%)    當月累計營收  \
# 公司代號 公司名稱
# 1101 台泥    5085162  9394240  4811678     -45.86       5.68  14479402
# 1102 亞泥    3165899  7905737  3408539     -59.95      -7.11  11071636
# 1103 嘉泥     108448   177060   125590     -38.75     -13.64    285508
# 1104 環球水泥   270638   479518   268120     -43.56       0.93    750157
# 1108 幸福水泥   168065   353189   197481     -52.41     -14.89    521254
#
# 4            去年累計營收  前期比較增減(%)
# 公司代號 公司名稱
# 1101 台泥    14429071       0.34
# 1102 亞泥    10178525       8.77
# 1103 嘉泥      297684      -4.09
# 1104 環球水泥    728601       2.95
# 1108 幸福水泥    517821       0.66

# %%
import numpy as np
a = np.where(pd.to_numeric(df['公司代號'],errors = 'coerce').isnull()==True)
a
# Out:
# (array([  7,  29,  50,  96, 149, 163, 194, 220, 226, 234, 264, 276, 282,
#         353, 412, 480, 519, 611, 632, 645, 681, 690, 739, 762, 779, 815,
#         831, 886, 887], dtype=int64),)

# %%
a = np.where(df['公司代號']=='合計')
a
# Out:
# (array([  7,  29,  50,  96, 149, 163, 194, 220, 226, 234, 264, 276, 282,
#         353, 412, 480, 519, 611, 632, 645, 681, 690, 739, 762, 779, 815,
#         831, 886, 887], dtype=int64),)

# %%
df = df[-pd.to_numeric(df['公司代號'],errors = 'coerce').isnull()]

# %%
df.head()
# Out:
# 4             當月營收     上月營收   去年當月營收  上月比較增減(%)  去年同月增減(%)    當月累計營收  \
# 公司代號 公司名稱
# 1101 台泥    5085162  9394240  4811678     -45.86       5.68  14479402
# 1102 亞泥    3165899  7905737  3408539     -59.95      -7.11  11071636
# 1103 嘉泥     108448   177060   125590     -38.75     -13.64    285508
# 1104 環球水泥   270638   479518   268120     -43.56       0.93    750157
# 1108 幸福水泥   168065   353189   197481     -52.41     -14.89    521254
#
# 4            去年累計營收  前期比較增減(%)
# 公司代號 公司名稱
# 1101 台泥    14429071       0.34
# 1102 亞泥    10178525       8.77
# 1103 嘉泥      297684      -4.09
# 1104 環球水泥    728601       2.95
# 1108 幸福水泥    517821       0.66

# %%
df = df.set_index(['公司代號','公司名稱'])

# %%
df = df.apply(pd.to_numeric)
df.head()
# Out:
# 4             當月營收     上月營收   去年當月營收  上月比較增減(%)  去年同月增減(%)    當月累計營收  \
# 公司代號 公司名稱
# 1101 台泥    5085162  9394240  4811678     -45.86       5.68  14479402
# 1102 亞泥    3165899  7905737  3408539     -59.95      -7.11  11071636
# 1103 嘉泥     108448   177060   125590     -38.75     -13.64    285508
# 1104 環球水泥   270638   479518   268120     -43.56       0.93    750157
# 1108 幸福水泥   168065   353189   197481     -52.41     -14.89    521254
#
# 4            去年累計營收  前期比較增減(%)
# 公司代號 公司名稱
# 1101 台泥    14429071       0.34
# 1102 亞泥    10178525       8.77
# 1103 嘉泥      297684      -4.09
# 1104 環球水泥    728601       2.95
# 1108 幸福水泥    517821       0.66

# %%
top5m_s = df.sort_values(by=['當月營收'], ascending=False)
top5m_s = top5m_s.head()
top5m_s



#top5m_s.plot.bar(y = '當月營收')#,fontproperties=myfont
# Out:
# 4               當月營收       上月營收     去年當月營收  上月比較增減(%)  去年同月增減(%)     當月累計營收  \
# 公司代號 公司名稱
# 2317 鴻海    265632525  414095017  277815099     -35.85      -4.38  679727542
# 4938 和碩     81645017  122634116   76834329     -33.42       6.26  204279133
# 2382 廣達     62862271   84925212   64293676     -25.97      -2.22  147787483
# 2330 台積電    60889055   78093827   64640562     -22.03      -5.80  138982882
# 3231 緯創     56850489   75735545   67361724     -24.93     -15.60  132586034
#
# 4             去年累計營收  前期比較增減(%)
# 公司代號 公司名稱
# 2317 鴻海    678421883       0.19
# 4938 和碩    197897477       3.22
# 2382 廣達    149078034      -0.86
# 2330 台積電   144381234      -3.73
# 3231 緯創    146762964      -9.65

# %%
top5pre_compare = df.sort_values(by=['上月比較增減(%)'], ascending=False)
top5pre_compare = top5pre_compare.head()
top5pre_compare
# Out:
# 4            當月營收   上月營收  去年當月營收  上月比較增減(%)  去年同月增減(%)  當月累計營收  去年累計營收  \
# 公司代號 公司名稱
# 2505 國揚實業   58009    681     429    8418.20   13421.91   58690   52071
# 6177 達麗     58510   4651   66505    1158.00     -12.02   63161  101975
# 3056 總太地產   19689   5025  416419     291.82     -95.27   24714  864619
# 5706 鳳凰旅遊  275944  91199  275699     202.57       0.08  367143  346047
# 6131 悠克國際    3111   1143   -6995     172.17     144.47    4254  -50527
#
# 4          前期比較增減(%)
# 公司代號 公司名稱
# 2505 國揚實業      12.71
# 6177 達麗       -38.06
# 3056 總太地產     -97.14
# 5706 鳳凰旅遊       6.09
# 6131 悠克國際     108.41

# %%
top5prem_s = df.sort_values(by=['去年當月營收'], ascending=False)
top5prem_s = top5prem_s.head()
top5prem_s
# Out:
# 4               當月營收       上月營收     去年當月營收  上月比較增減(%)  去年同月增減(%)     當月累計營收  \
# 公司代號 公司名稱
# 2317 鴻海    265632525  414095017  277815099     -35.85      -4.38  679727542
# 4938 和碩     81645017  122634116   76834329     -33.42       6.26  204279133
# 3231 緯創     56850489   75735545   67361724     -24.93     -15.60  132586034
# 2330 台積電    60889055   78093827   64640562     -22.03      -5.80  138982882
# 2382 廣達     62862271   84925212   64293676     -25.97      -2.22  147787483
#
# 4             去年累計營收  前期比較增減(%)
# 公司代號 公司名稱
# 2317 鴻海    678421883       0.19
# 4938 和碩    197897477       3.22
# 3231 緯創    146762964      -9.65
# 2330 台積電   144381234      -3.73
# 2382 廣達    149078034      -0.86

# %%
top5pre_compare = df.sort_values(by=['前期比較增減(%)'], ascending=False)
top5pre_compare = top5pre_compare.head()
top5pre_compare
# Out:
# 4            當月營收     上月營收  去年當月營收  上月比較增減(%)  去年同月增減(%)   當月累計營收  去年累計營收  \
# 公司代號 公司名稱
# 2527 宏璟    191053   230956   11082     -17.27    1623.99   422009   23215
# 9946 三發地產  450156   748197   20647     -39.83    2080.24  1198353  182968
# 5534 長虹    998054  1052650  124136      -5.18     704.00  2050704  354958
# 4994 傳奇    292548   295873   66544      -1.12     339.63   588421  119260
# 6225 天瀚       633     1249     263     -49.31     140.68     1882     492
#
# 4          前期比較增減(%)
# 公司代號 公司名稱
# 2527 宏璟      1717.82
# 9946 三發地產     554.95
# 5534 長虹       477.73
# 4994 傳奇       393.39
# 6225 天瀚       282.52
