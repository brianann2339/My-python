# %%
1+1 #要按shift+Enter
# Out:
# 2

# %%
import numpy as np
np.sin(1)
# Out:
# 0.8414709848078965

# %%
np.pi
# Out:
# 3.141592653589793

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 124342543wrewert

# %% [markdown]
# ###附註

# %% [markdown]
# ### 附註
# matplotlib = MATLAB PLOT LIB
# 中右上Code轉Markdown變註解
# 按TAB件可以看到要寫什麼

# %%
% matplotlib inline

# %%
plt.plot([1,37,25,68])

# %%
x = [1.2,1.7,2,3]
y = [9,0.5,2.4,-7]

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
np.random.rand(7)
# Out:
# array([0.35996845, 0.2391759 , 0.49145181, 0.26602858, 0.45015201,
#        0.61075436, 0.65441244])

# %%
plt.plot(np.random.rand(100))

# %%
x = np.linspace(0,10,1000)#0到10平均分1000個點
x
# Out:
# array([ 0.        ,  0.01001001,  0.02002002,  0.03003003,  0.04004004,
#         0.05005005,  0.06006006,  0.07007007,  0.08008008,  0.09009009,
#         0.1001001 ,  0.11011011,  0.12012012,  0.13013013,  0.14014014,
#         0.15015015,  0.16016016,  0.17017017,  0.18018018,  0.19019019,
#         0.2002002 ,  0.21021021,  0.22022022,  0.23023023,  0.24024024,
#         0.25025025,  0.26026026,  0.27027027,  0.28028028,  0.29029029,
#         0.3003003 ,  0.31031031,  0.32032032,  0.33033033,  0.34034034,
#         0.35035035,  0.36036036,  0.37037037,  0.38038038,  0.39039039,
#         0.4004004 ,  0.41041041,  0.42042042,  0.43043043,  0.44044044,
#         0.45045045,  0.46046046,  0.47047047,  0.48048048,  0.49049049,
#         0.5005005 ,  0.51051051,  0.52052052,  0.53053053,  0.54054054,
#         0.55055055,  0.56056056,  0.57057057,  0.58058058,  0.59059059,
#         0.6006006 ,  0.61061061,  0.62062062,  0.63063063,  0.64064064,
# ...

# %%
y = np.sin(x)

# %%
plt.plot(x,y)

# %%
plt.xkcd()
plt.plot(x,y)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

a1, b1 = (0., 0.)
r1 = 4.0
t = np.arange(0, 2*np.pi, 0.01)
x1 = a1 + r1 * np.cos(t)
y1 = b1 + r1 * np.sin(t)


a2, b2 = (0.,-0.5)
r2 = 1.5 #鼻子
x2 = a2 +  r2 * np.cos(t)
y2 = b2 + r2 * np.sin(t)


a3, b3 = (-1.5, 0.7)
r3 = 0.3 #左眼
x3 = a3 + r3 * np.cos(t)
y3 = b3 + r3 * np.sin(t)


a4, b4 = (1.5, 0.7)
r4 = 0.3 #右眼
x4 = a4 + r4 * np.cos(t)
y4 = b4 + r4 * np.sin(t)



a5, b5 = (-2.5, -0.9)
r5 = 1 #左臉頰
x5 = a5 + r5 * np.cos(t)
y5 = b5 + r5 * np.sin(t)


a6, b6 = (2.5, -0.9)
r6 = 1 #右臉頰
x6 = a6 + r6 * np.cos(t)
y6 = b6 + r6 * np.sin(t)

x7 = np.arange(math.pi/4, 3*math.pi/4, 0.01);#右眉毛
y7 = 2.3*np.sin(x7) 

x8 = np.arange(-3*math.pi/4, -1*math.pi/4, 0.01);#左眉毛
y8 = -2.3*np.sin(x8) 

x9 = np.arange(-1*math.pi/2, math.pi/2, 0.01);#嘴巴上
y9 = 0.1*np.sin(6*math.pi/4-x9) -2

x10 = np.arange(-1*math.pi/2, math.pi/2, 0.01);#嘴巴下
y10 = 1.5*np.sin(6*math.pi/4-x10) -2

a11, b11 = (0.5,0.3)
r11 = 0.2 #鼻子反光
x11 = a11 +  r11 * np.cos(t)
y11 = b11 + r11 * np.sin(t)

a12, b12 = (2.8,-0.3)
r12 = 0.2 #右臉反光
x12 = a12 +  r12 * np.cos(t)
y12 = b12 + r12 * np.sin(t)

a13, b13 = (-2.2,-0.3)
r13 = 0.2 #左臉反光
x13 = a13 +  r13 * np.cos(t)
y13 = b13 + r13 * np.sin(t)

fig = plt.figure() 
axes = fig.add_subplot(111) 
axes.plot(x1,y1)
axes.plot(x2,y2)
axes.plot(x3,y3)
axes.plot(x4,y4)
axes.plot(x5,y5)
axes.plot(x6,y6)
axes.plot(x7,y7)
axes.plot(x8,y8)
axes.plot(x9,y9)
axes.plot(x10,y10)
axes.plot(x11,y11)
axes.plot(x12,y12)
axes.plot(x13,y13)
axes.axis('equal')
# Out:
# (-4.399994673255666, 4.399999746345508, -4.399987951414783, 4.399998097591249)
